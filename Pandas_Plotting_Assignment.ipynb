# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijay8185/Assignments/blob/main/Pandas_Plotting_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignmnt : Create a dataframe with 5 rows and 4 columns using random.random
# # Pie plot
# # Transpose

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d = pd.DataFrame(np.random.random((5,4)),columns = ['A','B','C','D'])
d
# Out:
#           A         B         C         D
# 0  0.284203  0.781437  0.697914  0.969671
# 1  0.651325  0.464802  0.930904  0.103131
# 2  0.501850  0.937780  0.549982  0.170763
# 3  0.102906  0.059225  0.224149  0.424235
# 4  0.958698  0.334066  0.279908  0.632391

# %% [markdown]
# # Line Plot

# %%
d.plot()
# Out:
# <Axes: >

# %%
d[['B','C']].plot(linestyle='--',title='Pandas Plotting')
# Out:
# <Axes: title={'center': 'Pandas Plotting'}>

# %%
d.plot(subplots=True,figsize=(8,10),layout=(2,2))
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# # Bar Plot

# %%
d.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Pie PLot

# %%
d.plot(kind='pie',subplots=True,autopct='%.f%%',figsize=(12,12),layout=(2,2),title='Assignmemt : pie chart with DataFrame')
plt.legend()
plt.show()

# %% [markdown]
# # Transpose

# %%
d.T.plot.pie(subplots=True,figsize=(12,12),layout=(5,5))
# Out:
# array([[<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>,
#         <Axes: ylabel='3'>, <Axes: ylabel='4'>],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)
